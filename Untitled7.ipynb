# %%
import pandas as pd
data=pd.read_csv("Zomato data .csv")
print(data)
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
data.head(5)
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 143    False
# 144    False
# 145    False
# 146    False
# 147    False
# Length: 148, dtype: bool

# %%
data.shape
# Out:
# (148, 7)

# %%
data.describe()
# Out:
#              votes  approx_cost(for two people)
# count   148.000000                   148.000000
# mean    264.810811                   418.243243
# std     653.676951                   223.085098
# min       0.000000                   100.000000
# 25%       6.750000                   200.000000
# 50%      43.500000                   400.000000
# 75%     221.750000                   600.000000
# max    4884.000000                   950.000000

# %%
data.isnull()
# Out:
#       name  online_order  book_table   rate  votes  \
# 0    False         False       False  False  False
# 1    False         False       False  False  False
# 2    False         False       False  False  False
# 3    False         False       False  False  False
# 4    False         False       False  False  False
# ..     ...           ...         ...    ...    ...
# 143  False         False       False  False  False
# 144  False         False       False  False  False
# 145  False         False       False  False  False
# 146  False         False       False  False  False
# 147  False         False       False  False  False
#
#      approx_cost(for two people)  listed_in(type)
# 0                          False            False
# 1                          False            False
# 2                          False            False
# 3                          False            False
# 4                          False            False
# ...

# %%
data.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
data.dropna()
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
plt.figure(figsize=(20,5))
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.countplot(data=data.head(5),x="name")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # convert the data type of column-rate

# %%
def handleRate(value):
    value=str(value).split("/")
    value=value[0];
    return float(value)
    data["rate"]=data['rate'].apply(handleRate,inplace="True")
    print(data.head())

# %%
print(data)
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
def handleRate(value):
    value=str(value).split("/")
    value=value[0];
    return float(value)
    data["rate"]=data['rate'].apply(handleRate,inplace="True")
    print(data.head())

# %%
data
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
sns.countplot(data=data,x="listed_in(type)")
plt.xlabel("type of restaurents")
# Out:
# Text(0.5, 0, 'type of restaurents')

# %% [markdown]
# # conclusion - Majority of the restaurant falls in dinning category

# %%
data.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
grouped_data=data.groupby(["listed_in(type)"])["votes"].sum()
result=pd.DataFrame({'votes': grouped_data})
plt.plot(result,c="green",marker="o")
plt.xlabel("Type of restaurents",c="red",size=20)
plt.ylabel("votes",c="red",size=20)
# Out:
# Text(0, 0.5, 'votes')

# %% [markdown]
# # conclusion- dinning  restaurent  has received maximum vote

# %%
data.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
plt.figure(figsize=(15,5))
plt.hist(data =data,x="rate",bins=5)
plt.title("rating distribution")
plt.show()

# %% [markdown]
# #conclusion - the majority restaurents received rating from 3.5 to 4

# %% [markdown]
# # Average order spending by couples

# %%
data.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=data,x="approx_cost(for two people)")
plt.show()

# %% [markdown]
# conclusion- The most of the couple are spending approximate cost 300 rupees

# %%
data.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(data=data,x="online_order",y="rate")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[165], line 4
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
# ----> 4 sns.boxplot(data=data,x="online_order",y="rate")
#       5 plt.show()
#
# File /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/seaborn/categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
# ...

# %%
data={"online_order":['Yes','Yes','Yes','No','No'],
      'rate':["4.1","4.1","3.8","3.7","3.8"]}

data['rate']=pd.to_numeric(data['rate'],errors='coerce')
sns.boxplot(data=data,x='online_order',y='rate',hue="online_order")
plt.xlabel("type of mode")
plt.show()

# %% [markdown]
# #conclusion -offline order receive lower rating in comparision to online

# %%
import pandas as pd
data=pd.read_csv("Zomato data .csv")
print(data)
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
df=data.head(140)
df
# Out:
#                              name online_order book_table   rate  votes  \
# 0                           Jalsa          Yes        Yes  4.1/5    775
# 1                  Spice Elephant          Yes         No  4.1/5    787
# 2                 San Churro Cafe          Yes         No  3.8/5    918
# 3           Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4                   Grand Village           No         No  3.8/5    166
# ..                            ...          ...        ...    ...    ...
# 135                  Amma - Manae           No         No  3.1/5      0
# 136            Sri Sai Tiffannies           No         No  3.3/5      0
# 137          Hotel Andhra Speices           No         No  2.9/5      0
# 138  Sri Murari Family Restaurant           No         No  2.9/5      0
# 139        Aramane Donne Biriyani           No         No  2.9/5      0
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# ...

# %%
pivot_table=df.pivot_table(index='listed_in(type)',columns='online_order',aggfunc='size',fill_value=0)
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.heatmap(pivot_table,annot=True,fmt='d')
plt.title("Heatmap")
plt.xlabel("online order")
plt.ylabel("Listed In (Type)")
plt.show()

# %% [markdown]
# #CONCLUSION - Dinning restaurents primarily accept offline orders,whereas cafes primarily receive online orders.This suggest  that client prefer to place orders in person at restaurents
# but prefer online ordering at cafes.
